# %% [markdown]
# ### _**Data Creation**_

# %%
import pandas as pd
df = pd.read_csv("PFPROJECT_UPDATED.csv")
df
# Out:
#        Match_id match_type  event_match_number match_start_date  \
# 0     1354924.0        T20                 1.0        2/13/2023
# 1     1354924.0        T20                 1.0              NaN
# 2     1354924.0        T20                 1.0        2/13/2023
# 3     1354924.0        T20                 1.0        2/13/2023
# 4     1354924.0        T20                 1.0        2/13/2023
# ...         ...        ...                 ...              ...
# 1074        NaN        T20                 NaN        3/18/2024
# 1075  1416505.0        NaN                 NaN        3/18/2024
# 1076  1416505.0        T20                 NaN        3/18/2024
# 1077  1416505.0        T20                 NaN              NaN
# 1078  1416505.0        T20                 NaN        3/18/2024
#
#                  event_name event_short_name  innings       battingTeam  \
# 0     Pakistan Super League            PSL-8      1.0  Lahore Qalandars
# ...

# %% [markdown]
# ### _**Data Exploration (Initial Analysis)**_

# %%
df.head()
# Out:
#     Match_id match_type  event_match_number match_start_date  \
# 0  1354924.0        T20                 1.0        2/13/2023
# 1  1354924.0        T20                 1.0              NaN
# 2  1354924.0        T20                 1.0        2/13/2023
# 3  1354924.0        T20                 1.0        2/13/2023
# 4  1354924.0        T20                 1.0        2/13/2023
#
#               event_name event_short_name  innings       battingTeam  \
# 0  Pakistan Super League            PSL-8      1.0  Lahore Qalandars
# 1  Pakistan Super League            PSL-8      1.0               NaN
# 2  Pakistan Super League            PSL-8      1.0  Lahore Qalandars
# 3                    NaN            PSL-8      1.0  Lahore Qalandars
# 4  Pakistan Super League            PSL-8      1.0  Lahore Qalandars
#
#    battingOrder         batter
# 0           1.0   Fakhar Zaman
# 1           2.0     Mirza Baig
# 2           3.0        SD Hope
# 3           4.0  Kamran Ghulam
# ...

# %%
df.tail()
# Out:
#        Match_id match_type  event_match_number match_start_date  \
# 1074        NaN        T20                 NaN        3/18/2024
# 1075  1416505.0        NaN                 NaN        3/18/2024
# 1076  1416505.0        T20                 NaN        3/18/2024
# 1077  1416505.0        T20                 NaN              NaN
# 1078  1416505.0        T20                 NaN        3/18/2024
#
#                  event_name event_short_name  innings       battingTeam  \
# 1074  Pakistan Super League            PSL-9      2.0  Islamabad United
# 1075  Pakistan Super League            PSL-9      2.0  Islamabad United
# 1076  Pakistan Super League            PSL-9      2.0  Islamabad United
# 1077  Pakistan Super League            PSL-9      2.0  Islamabad United
# 1078  Pakistan Super League            PSL-9      2.0  Islamabad United
#
#       battingOrder         batter
# 1074           6.0     Imad Wasim
# 1075           7.0     Haider Ali
# 1076           8.0  Faheem Ashraf
# ...

# %%
df.sample()
# Out:
#       Match_id match_type  event_match_number match_start_date  \
# 608  1416475.0        T20                 4.0        2/19/2024
#
#                 event_name event_short_name  innings        battingTeam  \
# 608  Pakistan Super League            PSL-9      2.0  Quetta Gladiators
#
#      battingOrder  batter
# 608           1.0  JJ Roy

# %%
df.shape
# Out:
# (1079, 10)

# %%
df.size
# Out:
# 10790

# %%
df.columns
# Out:
# Index(['Match_id', 'match_type', 'event_match_number', 'match_start_date',
#        'event_name', 'event_short_name', 'innings', 'battingTeam',
#        'battingOrder', 'batter'],
#       dtype='object')

# %%
df[["battingOrder","event_name"]] # To take single or multiple columns data
# Out:
#       battingOrder             event_name
# 0              1.0  Pakistan Super League
# 1              2.0  Pakistan Super League
# 2              3.0  Pakistan Super League
# 3              4.0                    NaN
# 4              5.0  Pakistan Super League
# ...            ...                    ...
# 1074           6.0  Pakistan Super League
# 1075           7.0  Pakistan Super League
# 1076           8.0  Pakistan Super League
# 1077           9.0  Pakistan Super League
# 1078          10.0  Pakistan Super League
#
# [1079 rows x 2 columns]

# %%
df.dtypes
# Out:
# Match_id              float64
# match_type             object
# event_match_number    float64
# match_start_date       object
# event_name             object
# event_short_name       object
# innings               float64
# battingTeam            object
# battingOrder          float64
# batter                 object
# dtype: object

# %%
# This function make list by using commas
df.values
# Out:
# array([[1354924.0, 'T20', 1.0, ..., 'Lahore Qalandars', 1.0,
#         'Fakhar Zaman'],
#        [1354924.0, 'T20', 1.0, ..., nan, 2.0, 'Mirza Baig'],
#        [1354924.0, 'T20', 1.0, ..., 'Lahore Qalandars', 3.0, 'SD Hope'],
#        ...,
#        [1416505.0, 'T20', nan, ..., 'Islamabad United', 8.0,
#         'Faheem Ashraf'],
#        [1416505.0, 'T20', nan, ..., 'Islamabad United', 9.0,
#         'Naseem Shah'],
#        [1416505.0, 'T20', nan, ..., 'Islamabad United', 10.0, nan]],
#       dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1079, step=1)

# %%
df.info()  # Overview of data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1079 entries, 0 to 1078
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Match_id            1015 non-null   float64
#  1   match_type          989 non-null    object
#  2   event_match_number  878 non-null    float64
#  3   match_start_date    995 non-null    object
#  4   event_name          1011 non-null   object
#  5   event_short_name    1015 non-null   object
#  6   innings             1014 non-null   float64
#  7   battingTeam         996 non-null    object
#  8   battingOrder        991 non-null    float64
#  9   batter              1027 non-null   object
# dtypes: float64(4), object(6)
# memory usage: 84.4+ KB

# %%
df.describe() # Gives numerical value of data set
# Out:
#            Match_id  event_match_number      innings  battingOrder
# count  1.015000e+03          878.000000  1014.000000    991.000000
# mean   1.384472e+06           15.703872     1.524655      4.823411
# std    3.076401e+04            8.682215     0.499638      2.743237
# min    1.354924e+06            1.000000     1.000000      1.000000
# 25%    1.354940e+06            8.000000     1.000000      3.000000
# 50%    1.354956e+06           15.000000     2.000000      5.000000
# 75%    1.416487e+06           23.000000     2.000000      7.000000
# max    1.416505e+06           30.000000     2.000000     11.000000

# %%
df.describe(include="all")
# Out:
#             Match_id match_type  event_match_number match_start_date  \
# count   1.015000e+03        989          878.000000              995
# unique           NaN          1                 NaN               57
# top              NaN        T20                 NaN        3/12/2023
# freq             NaN        989                 NaN               38
# mean    1.384472e+06        NaN           15.703872              NaN
# std     3.076401e+04        NaN            8.682215              NaN
# min     1.354924e+06        NaN            1.000000              NaN
# 25%     1.354940e+06        NaN            8.000000              NaN
# 50%     1.354956e+06        NaN           15.000000              NaN
# 75%     1.416487e+06        NaN           23.000000              NaN
# max     1.416505e+06        NaN           30.000000              NaN
#
#                    event_name event_short_name      innings       battingTeam  \
# ...

# %%
df.isnull()
# Out:
#       Match_id  match_type  event_match_number  match_start_date  event_name  \
# 0        False       False               False             False       False
# 1        False       False               False              True       False
# 2        False       False               False             False       False
# 3        False       False               False             False        True
# 4        False       False               False             False       False
# ...        ...         ...                 ...               ...         ...
# 1074      True       False                True             False       False
# 1075     False        True                True             False       False
# 1076     False       False                True             False       False
# 1077     False       False                True              True       False
# 1078     False       False                True             False       False
#
# ...

# %%
df.isnull().sum() # Count the missing values
# Out:
# Match_id               64
# match_type             90
# event_match_number    201
# match_start_date       84
# event_name             68
# event_short_name       64
# innings                65
# battingTeam            83
# battingOrder           88
# batter                 52
# dtype: int64

# %% [markdown]
# ### _**Data Cleaning**_

# %%
# It can also be used for rows
df.rename(columns={"event_short_name":"Event names", "batter":"batsman"},inplace=True)
df
# Out:
#        Match_id match_type  event_match_number match_start_date  \
# 0     1354924.0        T20                 1.0        2/13/2023
# 1     1354924.0        T20                 1.0              NaN
# 2     1354924.0        T20                 1.0        2/13/2023
# 3     1354924.0        T20                 1.0        2/13/2023
# 4     1354924.0        T20                 1.0        2/13/2023
# ...         ...        ...                 ...              ...
# 1074        NaN        T20                 NaN        3/18/2024
# 1075  1416505.0        NaN                 NaN        3/18/2024
# 1076  1416505.0        T20                 NaN        3/18/2024
# 1077  1416505.0        T20                 NaN              NaN
# 1078  1416505.0        T20                 NaN        3/18/2024
#
#                  event_name Event names  innings       battingTeam  \
# 0     Pakistan Super League       PSL-8      1.0  Lahore Qalandars
# ...

# %%
df.dropna() # To drop missing values
# Out:
#        Match_id match_type  event_match_number match_start_date  \
# 0     1354924.0        T20                 1.0        2/13/2023
# 2     1354924.0        T20                 1.0        2/13/2023
# 4     1354924.0        T20                 1.0        2/13/2023
# 8     1354924.0        T20                 1.0        2/13/2023
# 11    1354924.0        T20                 1.0        2/13/2023
# ...         ...        ...                 ...              ...
# 1001  1416501.0        T20                30.0        3/12/2024
# 1002  1416501.0        T20                30.0        3/12/2024
# 1003  1416501.0        T20                30.0        3/12/2024
# 1005  1416501.0        T20                30.0        3/12/2024
# 1007  1416501.0        T20                30.0        3/12/2024
#
#                  event_name Event names  innings        battingTeam  \
# 0     Pakistan Super League       PSL-8      1.0   Lahore Qalandars
# ...

# %%
df.fillna(56) # To fill missing values
# Out:
#        Match_id match_type  event_match_number match_start_date  \
# 0     1354924.0        T20                 1.0        2/13/2023
# 1     1354924.0        T20                 1.0               56
# 2     1354924.0        T20                 1.0        2/13/2023
# 3     1354924.0        T20                 1.0        2/13/2023
# 4     1354924.0        T20                 1.0        2/13/2023
# ...         ...        ...                 ...              ...
# 1074       56.0        T20                56.0        3/18/2024
# 1075  1416505.0         56                56.0        3/18/2024
# 1076  1416505.0        T20                56.0        3/18/2024
# 1077  1416505.0        T20                56.0               56
# 1078  1416505.0        T20                56.0        3/18/2024
#
#                  event_name Event names  innings       battingTeam  \
# 0     Pakistan Super League       PSL-8      1.0  Lahore Qalandars
# ...

# %%
df=df.drop(columns=["match_start_date"])
df
# Out:
#        Match_id match_type             event_name Event names  innings  \
# 0     1354924.0        T20  Pakistan Super League       PSL-8      1.0
# 1     1354924.0        T20  Pakistan Super League       PSL-8      1.0
# 2     1354924.0        T20  Pakistan Super League       PSL-8      1.0
# 3     1354924.0        T20                    NaN       PSL-8      1.0
# 4     1354924.0        T20  Pakistan Super League       PSL-8      1.0
# ...         ...        ...                    ...         ...      ...
# 1074        NaN        T20  Pakistan Super League       PSL-9      2.0
# 1075  1416505.0        NaN  Pakistan Super League       PSL-9      2.0
# 1076  1416505.0        T20  Pakistan Super League       PSL-9      2.0
# 1077  1416505.0        T20  Pakistan Super League       PSL-9      2.0
# 1078  1416505.0        T20  Pakistan Super League       PSL-9      2.0
#
#            battingTeam  battingOrder        batsman
# 0     Lahore Qalandars           1.0   Fakhar Zaman
# ...

# %%
# To drop columns
del df["Event names"]
df
# Out:
#        Match_id match_type  event_match_number match_start_date  \
# 0     1354924.0        T20                 1.0        2/13/2023
# 1     1354924.0        T20                 1.0              NaN
# 2     1354924.0        T20                 1.0        2/13/2023
# 3     1354924.0        T20                 1.0        2/13/2023
# 4     1354924.0        T20                 1.0        2/13/2023
# ...         ...        ...                 ...              ...
# 1074        NaN        T20                 NaN        3/18/2024
# 1075  1416505.0        NaN                 NaN        3/18/2024
# 1076  1416505.0        T20                 NaN        3/18/2024
# 1077  1416505.0        T20                 NaN              NaN
# 1078  1416505.0        T20                 NaN        3/18/2024
#
#                  event_name  innings  battingOrder        batsman
# 0     Pakistan Super League      1.0           1.0   Fakhar Zaman
# ...

# %%
# To drop rows
df = df.drop(4)
df
# Out:
#        Match_id match_type  event_match_number match_start_date  \
# 0     1354924.0        T20                 1.0        2/13/2023
# 1     1354924.0        T20                 1.0              NaN
# 2     1354924.0        T20                 1.0        2/13/2023
# 3     1354924.0        T20                 1.0        2/13/2023
# 5     1354924.0        T20                 1.0        2/13/2023
# ...         ...        ...                 ...              ...
# 1074        NaN        T20                 NaN        3/18/2024
# 1075  1416505.0        NaN                 NaN        3/18/2024
# 1076  1416505.0        T20                 NaN        3/18/2024
# 1077  1416505.0        T20                 NaN              NaN
# 1078  1416505.0        T20                 NaN        3/18/2024
#
#                  event_name  innings  battingOrder        batsman
# 0     Pakistan Super League      1.0           1.0   Fakhar Zaman
# ...

# %% [markdown]
# ### _**Data Manipulation**_

# %%
df.insert(5, "centuries", 5)  # To add new columns by giving specific index and values
df
# Out:
#        Match_id match_type  event_match_number match_start_date  \
# 0     1354924.0        T20                 1.0        2/13/2023
# 1     1354924.0        T20                 1.0              NaN
# 2     1354924.0        T20                 1.0        2/13/2023
# 3     1354924.0        T20                 1.0        2/13/2023
# 5     1354924.0        T20                 1.0        2/13/2023
# ...         ...        ...                 ...              ...
# 1074        NaN        T20                 NaN        3/18/2024
# 1075  1416505.0        NaN                 NaN        3/18/2024
# 1076  1416505.0        T20                 NaN        3/18/2024
# 1077  1416505.0        T20                 NaN              NaN
# 1078  1416505.0        T20                 NaN        3/18/2024
#
#                  event_name  centuries  innings  battingOrder        batsman
# 0     Pakistan Super League          5      1.0           1.0   Fakhar Zaman
# ...

# %%
df['In.mean']=df["innings"].mean()
df
# Out:
#               Match_id match_type  event_match_number match_start_date  \
# 0            1354924.0        T20                 1.0        2/13/2023
# 1            1354924.0        T20                 1.0              NaN
# 2            1354924.0        T20                 1.0        2/13/2023
# 3             134565.0        T20                 1.0         0.000076
# 5            1354924.0        T20                 1.0        2/13/2023
# ...                ...        ...                 ...              ...
# 1074  Lahore Qalandars        T20                 NaN        3/18/2024
# 1075         1416505.0        NaN                 NaN        3/18/2024
# 1076         1416505.0        T20                 NaN        3/18/2024
# 1077         1416505.0        T20                 NaN              NaN
# 1078         1416505.0        T20                 NaN        3/18/2024
#
#                  event_name  innings  battingOrder        batsman   In.mean  \
# ...

# %%
df['Match_id'].fillna(('Lahore Qalandars'),inplace=True)
df['Match_id']
# Out:
# 0              1354924.0
# 1              1354924.0
# 2              1354924.0
# 3               134565.0
# 5              1354924.0
#               ...
# 1074    Lahore Qalandars
# 1075           1416505.0
# 1076           1416505.0
# 1077           1416505.0
# 1078           1416505.0
# Name: Match_id, Length: 1078, dtype: object

# %%
df["startingdate"]=df["centuries"]+df["innings"]
df
# Out:
#               Match_id match_type  event_match_number match_start_date  \
# 0            1354924.0        T20                 1.0        2/13/2023
# 1            1354924.0        T20                 1.0              NaN
# 2            1354924.0        T20                 1.0        2/13/2023
# 3            1354924.0        T20                 1.0        2/13/2023
# 5            1354924.0        T20                 1.0        2/13/2023
# ...                ...        ...                 ...              ...
# 1074  Lahore Qalandars        T20                 NaN        3/18/2024
# 1075         1416505.0        NaN                 NaN        3/18/2024
# 1076         1416505.0        T20                 NaN        3/18/2024
# 1077         1416505.0        T20                 NaN              NaN
# 1078         1416505.0        T20                 NaN        3/18/2024
#
#                  event_name  centuries  innings  battingOrder        batsman  \
# ...

# %% [markdown]
# ### _**Data Selection**_

# %%
df.loc[1075,"match_type"] # To find values by using their row or column name .loc is used

# %%
# To add rows
df.loc[3]=[134565.0, "T20", 1.0, 2/13/2024, "Pakistan Super League", 5, 1.0, 1.0, "Babar Azam", 1.525173, 6.0]
df
# Out:
#               Match_id match_type  event_match_number match_start_date  \
# 0            1354924.0        T20                 1.0        2/13/2023
# 1            1354924.0        T20                 1.0              NaN
# 2            1354924.0        T20                 1.0        2/13/2023
# 3             134565.0        T20                 1.0         0.000076
# 5            1354924.0        T20                 1.0        2/13/2023
# ...                ...        ...                 ...              ...
# 1074  Lahore Qalandars        T20                 NaN        3/18/2024
# 1075         1416505.0        NaN                 NaN        3/18/2024
# 1076         1416505.0        T20                 NaN        3/18/2024
# 1077         1416505.0        T20                 NaN              NaN
# 1078         1416505.0        T20                 NaN        3/18/2024
#
#                  event_name  centuries  innings  battingOrder        batsman  \
# ...

# %%
df.loc[5]
# Out:
# Match_id                          1354924.0
# match_type                              T20
# event_match_number                      1.0
# match_start_date                  2/13/2023
# event_name            Pakistan Super League
# centuries                                 5
# innings                                 1.0
# battingOrder                            NaN
# batsman                       Hussain Talat
# In.mean                            1.525173
# startingdate                            6.0
# Name: 5, dtype: object

# %%
df.loc[567, ["match_type", "match_start_date"]]
# Out:
# match_type                T20
# match_start_date    2/17/2024
# Name: 567, dtype: object

# %%
df.iloc[3,8] # To find row or columns by taking index numbers .iloc is used
# Out:
# 'Babar Azam'

# %%
df.iloc[[3,4]]
# Out:
#     Match_id match_type  event_match_number match_start_date  \
# 3   134565.0        T20                 1.0         0.000076
# 5  1354924.0        T20                 1.0        2/13/2023
#
#               event_name  centuries  innings  battingOrder        batsman  \
# 3  Pakistan Super League          5      1.0           1.0     Babar Azam
# 5  Pakistan Super League          5      1.0           NaN  Hussain Talat
#
#     In.mean  startingdate
# 3  1.525173           6.0
# 5  1.525173           6.0

# %%
df.iloc[[3,4],7]
# Out:
# 3    1.0
# 5    NaN
# Name: battingOrder, dtype: float64

# %% [markdown]
# ### _**Statistical Analysis**_

# %%
df["battingOrder"].mean()
# Out:
# 4.820202020202021

# %%
df["battingOrder"].median()
# Out:
# 5.0

# %%
df["battingOrder"].mode
# Out:
# <bound method Series.mode of 0        1.0
# 1        2.0
# 2        3.0
# 3        1.0
# 5        NaN
#         ...
# 1074     6.0
# 1075     7.0
# 1076     8.0
# 1077     9.0
# 1078    10.0
# Name: battingOrder, Length: 1078, dtype: float64>

# %%
df["battingOrder"].min()
# Out:
# 1.0

# %%
df["battingOrder"].max()
# Out:
# 11.0

# %%
df["battingOrder"].std()
# Out:
# 2.7471827576149654

# %% [markdown]
# ### _**Handle Duplicates**_

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of               Match_id match_type  event_match_number match_start_date  \
# 0            1354924.0        T20                 1.0        2/13/2023
# 1            1354924.0        T20                 1.0              NaN
# 2            1354924.0        T20                 1.0        2/13/2023
# 3             134565.0        T20                 1.0         0.000076
# 5            1354924.0        T20                 1.0        2/13/2023
# ...                ...        ...                 ...              ...
# 1074  Lahore Qalandars        T20                 NaN        3/18/2024
# 1075         1416505.0        NaN                 NaN        3/18/2024
# 1076         1416505.0        T20                 NaN        3/18/2024
# 1077         1416505.0        T20                 NaN              NaN
# 1078         1416505.0        T20                 NaN        3/18/2024
#
# ...

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of               Match_id match_type  event_match_number match_start_date  \
# 0            1354924.0        T20                 1.0        2/13/2023
# 1            1354924.0        T20                 1.0              NaN
# 2            1354924.0        T20                 1.0        2/13/2023
# 3             134565.0        T20                 1.0         0.000076
# 5            1354924.0        T20                 1.0        2/13/2023
# ...                ...        ...                 ...              ...
# 1074  Lahore Qalandars        T20                 NaN        3/18/2024
# 1075         1416505.0        NaN                 NaN        3/18/2024
# 1076         1416505.0        T20                 NaN        3/18/2024
# 1077         1416505.0        T20                 NaN              NaN
# 1078         1416505.0        T20                 NaN        3/18/2024
#
# ...

# %%
df["centuries"] = df["centuries"].replace(5, 7)
df
# Out:
#               Match_id match_type  event_match_number match_start_date  \
# 0            1354924.0        T20                 1.0        2/13/2023
# 1            1354924.0        T20                 1.0              NaN
# 2            1354924.0        T20                 1.0        2/13/2023
# 3             134565.0        T20                 1.0         0.000076
# 5            1354924.0        T20                 1.0        2/13/2023
# ...                ...        ...                 ...              ...
# 1074  Lahore Qalandars        T20                 NaN        3/18/2024
# 1075         1416505.0        NaN                 NaN        3/18/2024
# 1076         1416505.0        T20                 NaN        3/18/2024
# 1077         1416505.0        T20                 NaN              NaN
# 1078         1416505.0        T20                 NaN        3/18/2024
#
#                  event_name  centuries  innings  battingOrder        batsman  \
# ...

# %% [markdown]
# ### _**Change Data Type**_

# %%
df["battingOrder"] = df["battingOrder"].astype(bool)
df.dtypes
# Out:
# Match_id               object
# match_type             object
# event_match_number    float64
# match_start_date       object
# event_name             object
# centuries               int64
# innings               float64
# battingOrder             bool
# batsman                object
# In.mean               float64
# startingdate          float64
# dtype: object

# %% [markdown]
# ### _**Analyzing Data**_

# %%
df.groupby("event_name").describe()
df
# Out:
#               Match_id match_type  event_match_number match_start_date  \
# 0            1354924.0        T20                 1.0        2/13/2023
# 1            1354924.0        T20                 1.0              NaN
# 2            1354924.0        T20                 1.0        2/13/2023
# 3             134565.0        T20                 1.0         0.000076
# 5            1354924.0        T20                 1.0        2/13/2023
# ...                ...        ...                 ...              ...
# 1074  Lahore Qalandars        T20                 NaN        3/18/2024
# 1075         1416505.0        NaN                 NaN        3/18/2024
# 1076         1416505.0        T20                 NaN        3/18/2024
# 1077         1416505.0        T20                 NaN              NaN
# 1078         1416505.0        T20                 NaN        3/18/2024
#
#                  event_name  centuries  innings  battingOrder        batsman  \
# ...

# %%
df.groupby('centuries')['innings'].sum()
# Out:
# centuries
# 7    1545.0
# Name: innings, dtype: float64

# %%
df.sort_values(by='innings', ascending=False)
# Out:
#               Match_id match_type  event_match_number match_start_date  \
# 540   Lahore Qalandars        T20                 NaN        3/17/2023
# 608          1416475.0        T20                 4.0        2/19/2024
# 591          1416474.0        T20                 3.0        2/18/2024
# 592          1416474.0        T20                 3.0        2/18/2024
# 593          1416474.0        T20                 3.0        2/18/2024
# ...                ...        ...                 ...              ...
# 1044         1416504.0        T20                 NaN        3/16/2024
# 1049         1416504.0        T20                 NaN        3/16/2024
# 1054         1416504.0        T20                 NaN        3/16/2024
# 1067         1416505.0        T20                 NaN        3/18/2024
# 1070         1416505.0        T20                 NaN        3/18/2024
#
#                  event_name  centuries  innings  battingOrder         batsman  \
# ...

# %%
# axis=0 for rows, axis=1 for columns
df.filter(like='innings', axis=1)
# Out:
#       innings
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 5         1.0
# ...       ...
# 1074      2.0
# 1075      2.0
# 1076      2.0
# 1077      2.0
# 1078      2.0
#
# [1078 rows x 1 columns]

# %% [markdown]
# ### _**Visualization**_

# %%
df["battingOrder"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='battingOrder'>

# %%
df["battingOrder"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='battingOrder'>

# %%
df["battingOrder"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["battingOrder"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["battingOrder"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='battingOrder'>

# %%
df["battingOrder"].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
df["battingOrder"].value_counts().plot(kind="area")
# Out:
# <Axes: xlabel='battingOrder'>

# %% [markdown]
# ### _**Final Export**_

# %%
df = pd.read_csv("PFPROJECT_UPDATED.csv")
df
df.to_excel("new_project.xlsx", sheet_name="secsheet")
